# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline


file_path = 'Foods.xlsx'
foods_data = pd.read_excel(file_path)


x = foods_data['Calories Per Dollar']
y = foods_data['g Protein/100 calories']

degree = 4
polyreg = make_pipeline(PolynomialFeatures(degree), LinearRegression())
polyreg.fit(x.values.reshape(-1, 1), y.values)

# Predictions for the polynomial model
y_poly_pred = polyreg.predict(x.values.reshape(-1, 1))

# Calculate MSE and R^2 for the polynomial model
mse_poly = mean_squared_error(y, y_poly_pred)
r2_poly = r2_score(y, y_poly_pred)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.plot(x, y_poly_pred, color='green')
plt.title('Polynomial Regression (Degree 4)')
plt.xlabel('Calories per Dollar')
plt.ylabel('Grams of Protein per 100 Calories')
plt.grid(True)
plt.show()

print(f'MSE: {mse_poly:.2f}')
print(f'r^2: {r2_poly:.3f}')
print(f'correlation: {correlation_coefficient:.2f}')
# Out:
# MSE: 26.20
# r^2: 0.213
# correlation: -0.31

# %%
print("\n20 cheapest foods ")
foods_data_default = foods_data.sort_values(by='Calories Per Dollar', ascending=False)
foods_data_default.head(50).reset_index(drop=True)
# Out:
# 20 cheapest foods
#                                 Item  Before Tax Price  Calories Per Dollar  \
# 0                              Flour              1.68                 4464
# 1                        White Bread              0.78                 3333
# 2                              Sugar              2.98                 2854
# 3                               Rice              6.53                 2320
# 4                         Plain Oats              7.89                 2148
# 5                              Ramen              2.34                 1949
# 6                         Angel Hair              1.00                 1600
# 7                        White Pasta              1.00                 1600
# 8                       Bread Crumbs              1.08                 1556
# 9                      Peanut Butter             10.99                 1487
# 10                 Whole Wheat Pasta              1.00                 1470
# ...

# %%
foods_data['Calorie to Protein Ratio'] = foods_data['Calories Per Dollar']/foods_data['Protein Per Dollar']

# Sort the foods based on the highest calorie/protein ratio
optimal_foods = foods_data.sort_values(by='Calorie to Protein Ratio', ascending=True)
optimal_foods.head(50).reset_index(drop=True)
# Out:
#                               Item  Before Tax Price  Calories Per Dollar  \
# 0             Albacore Canned Tuna             14.89                  113
# 1           Pork Sirloin Tip Roast              1.99                  203
# 2                          Pollock              5.98                  140
# 3                          Chicken              2.09                  239
# 4                          Tilapia              6.98                  167
# 5                   Canned Chicken              0.98                  115
# 6              Egg Whites (carton)              2.36                  106
# 7                        Cytosport             45.99                  228
# 8         Turkey Thanksgiving Sale              1.08                  407
# 9   Sliced Turkey Breast(Jeanie O)              5.98                   78
# 10                      Beef Jerky             14.99                   96
# 11                          Salmon              1.42                   85
# ...

# %%
print("Based on my analysis of 106 foods, chicken, turkey, beans, and green yogurt are some foods that are high in protein, lower in calories, and relatively inexpensive.")
# Out:
# Based on my analysis of 106 foods, chicken, turkey, beans, and green yogurt are some foods that are high in protein, lower in calories, and relatively inexpensive.
